# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Duolingo language trend analysis (2020 - 2024)
# ## Exploring most popular language over 5 years

# %% [markdown]
# ## Data Loading and Inspection

# %%
data = pd.read_csv("C:/Users/deepi/Downloads/duolingo_language_report_by_country.csv")

# %% [markdown]
# ## Top rows of the data

# %%
data.head()

# %% [markdown]
# ## Changing column names

# %%
dataset = data.rename(columns = {
    'pop1_2020' : 'first_popular_2020',
    'pop2_2020' : 'second_popular_2020',
    'pop1_2021' : 'first_popular_2021',
    'pop2_2021' : 'second_popular_2021',
    'pop1_2022' : 'first_popular_2022',
    'pop2_2022' : 'second_popular_2022',
    'pop1_2023' : 'first_popular_2023',
    'pop2_2023' : 'second_popular_2023',
    'pop1_2024' : 'first_popular_2024',
    'pop2_2024' : 'second_popular_2024'})

# %% [markdown]
# ## Displaying the column names

# %%
dataset.columns

# %% [markdown]
# ## Displaying the Dataset

# %%
dataset

# %% [markdown]
# ## Top few rows of the dataset

# %%
dataset.head()

# %% [markdown]
# ## Last few rows of the dataset

# %%
dataset.tail()

# %% [markdown]
# ## Checking for Null values

# %%
dataset.isnull().sum()

# %% [markdown]
# ## Basic Information about the data

# %%
dataset.info()

# %% [markdown]
# ## Shape of the data

# %%
dataset.shape

# %% [markdown]
# ## Type of data

# %%
dataset.dtypes

# %% [markdown]
# ## Description about the data

# %%
dataset.describe()

# %% [markdown]
# ## Number 0f Unique values

# %%
dataset.nunique()
